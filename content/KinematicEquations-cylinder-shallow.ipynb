# %% [markdown]
# ### Deriving the non-linear cylinder 3D shallow kinematics

# %%
from sympy import Function, Symbol, sqrt, cos, sin
from sympy import init_printing, simplify, expand

r = Symbol('r', constant=True)
x = Symbol('x')
y = Symbol('y')
z = Symbol('z')
u = Function('u')(x,y,z)
v = Function('v')(x,y,z)
w = Function('w')(x,y,z)
R = Function('R')(z)

NL = 1 # NOTE set to 1 for full nonlinear relations, 0 for linear relations

# Global coordinates
X1 = R*cos(y/r)
X2 = R*sin(y/r)
X3 = -x

# Local coordinates
x1 = x
x2 = y
x3 = z

H1 = sqrt(X1.diff(x1)**2 + X2.diff(x1)**2 + X3.diff(x1)**2)
H2 = sqrt(X1.diff(x2)**2 + X2.diff(x2)**2 + X3.diff(x2)**2)
H3 = sqrt(X1.diff(x3)**2 + X2.diff(x3)**2 + X3.diff(x3)**2)
                
w1 = ((H1*w).diff(x2) - (H2*v).diff(x3))/(2*H2*H3)
w2 = ((H1*u).diff(x3) - (H3*w).diff(x1))/(2*H1*H3)
w3 = ((H2*v).diff(x1) - (H1*u).diff(x2))/(2*H1*H2)

e11 = u.diff(x1)/H1 + v*H1.diff(x2)/(H1*H2) + w*H1.diff(x3)/(H1*H3)
e22 = u*H2.diff(x1)/(H1*H2) + v.diff(x2)/H2 + w*H2.diff(x3)/(H2*H3)
e33 = u*H3.diff(x1)/(H1*H3) + v*H3.diff(x2)/(H2*H3) + w.diff(x3)/H3
e12 = H1*(u/H1).diff(x2)/H2 + H2*(v/H2).diff(x1)/H1
e13 = H1*(u/H1).diff(x3)/H3 + H3*(w/H3).diff(x1)/H1
e23 = H2*(v/H2).diff(x3)/H3 + H3*(w/H3).diff(x2)/H2

ep11 = ((e13/2 - w2)**2 + (e12/2 + w3)**2 + e11**2)/2*NL + e11
ep22 = ((e23/2 + w1)**2 + (e12/2 - w3)**2 + e22**2)/2*NL + e22
ep33 = ((e23/2 - w1)**2 + (e13/2 + w2)**2 + e33**2)/2*NL + e33
ep12 = ((e23/2 + w1)*(e13/2 - w2) + e11*(e12/2 - w3) + e22*(e12/2 + w3))*NL + e12
ep13 = (e33*(e13/2 - w2) + e11*(e13/2 + w2) + (e23/2 - w1)*(e12/2 + w3))*NL + e13
ep23 = (e22*(e23/2 - w1) + e33*(e23/2 + w1) + (e13/2 + w2)*(e12/2 - w3))*NL + e23

exx = ep11
eyy = ep22
ezz = ep33
gxy = ep12
gxz = ep13
gyz = ep23

# %% [markdown]
# Printing kinematic equations
# ---
# The following order is printed next:
#
# $\varepsilon_{xx}$
# $\varepsilon_{yy}$
# $\varepsilon_{zz}$
# $\gamma_{xy}$
# $\gamma_{xz}$
# $\gamma_{yz}$

# %%
init_printing()

# %%
simplify(exx)
# Out:
#                 2                                    2                   2
# ⎛∂             ⎞                     ⎛∂             ⎞    ⎛∂             ⎞
# ⎜──(u(x, y, z))⎟                     ⎜──(v(x, y, z))⎟    ⎜──(w(x, y, z))⎟
# ⎝∂x            ⎠    ∂                ⎝∂x            ⎠    ⎝∂x            ⎠
# ───────────────── + ──(u(x, y, z)) + ───────────────── + ─────────────────
#         2           ∂x                       2                   2

# %%
simplify(eyy)
# Out:
#                                                                                ↪
#          _______                     ⎛      _______                            ↪
#         ╱  2                         ⎜     ╱  2                                ↪
#  2     ╱  R (z)  ∂                 2 ⎜    ╱  R (z)             d             ╱ ↪
# r ⋅   ╱   ───── ⋅──(v(x, y, z))   r ⋅⎜   ╱   ───── ⋅w(x, y, z)⋅──(R(z)) +   ╱  ↪
#      ╱      2    ∂y                  ⎜  ╱      2               dz         ╲╱   ↪
#    ╲╱      r                         ⎝╲╱      r                                ↪
# ─────────────────────────────── + ──────────────────────────────────────────── ↪
#               2                                                                ↪
#              R (z)                                                 4    ⎛d     ↪
#                                                                 2⋅R (z)⋅⎜──(R( ↪
#                                                                         ⎝dz    ↪
#                                                                                ↪
#
# ↪                                    2                                         ↪
# ↪  _____________                    ⎞       ⎛          _______      __________ ↪
# ↪ ╱           2                     ⎟       ⎜         ╱  2         ╱           ↪
# ↪   ⎛d       ⎞        ∂             ⎟     2 ⎜        ╱  R (z)     ╱  ⎛d        ↪
# ↪   ⎜──(R(z))⎟  ⋅R(z)⋅──(v(x, y, z))⎟    r ⋅⎜- 2⋅   ╱   ───── ⋅  ╱   ⎜──(R(z)) ↪
# ↪   ⎝dz      ⎠        ∂y            ⎟       ⎜      ╱      2    ╲╱    ⎝dz       ↪
# ↪                                   ⎠       ⎝    ╲╱      r                     ↪
# ↪ ──────────────────────────────────── + ───────────────────────────────────── ↪
# ↪     2                                                                        ↪
# ↪    ⎞                                                                         ↪
# ↪ z))⎟                                                                         ↪
# ↪    ⎠                                                                         ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ___                                 _____________                            ↪
# ↪  2                                 ╱           2                             ↪
# ↪ ⎞                   d             ╱  ⎛d       ⎞    2    ∂                 2  ↪
# ↪ ⎟  ⋅R(z)⋅v(x, y, z)⋅──(R(z)) +   ╱   ⎜──(R(z))⎟  ⋅R (z)⋅──(w(x, y, z)) + R ( ↪
# ↪ ⎠                   dz         ╲╱    ⎝dz      ⎠         ∂y                   ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                            4                                 ↪
# ↪                             6    ⎛d       ⎞                                  ↪
# ↪                          8⋅R (z)⋅⎜──(R(z))⎟                                  ↪
# ↪                                  ⎝dz      ⎠                                  ↪
# ↪                                                                              ↪
#
# ↪                               2                                              ↪
# ↪                              ⎞                                               ↪
# ↪              2               ⎟                                               ↪
# ↪    ⎛d       ⎞  ∂             ⎟                       2                       ↪
# ↪ z)⋅⎜──(R(z))⎟ ⋅──(w(x, y, z))⎟     2 ⎛∂             ⎞               ⎛d       ↪
# ↪    ⎝dz      ⎠  ∂y            ⎟    r ⋅⎜──(u(x, y, z))⎟    w(x, y, z)⋅⎜──(R(z) ↪
# ↪                              ⎠       ⎝∂y            ⎠               ⎝dz      ↪
# ↪ ─────────────────────────────── + ──────────────────── + ─────────────────── ↪
# ↪                                            2                          7/2    ↪
# ↪                                         2⋅R (z)          ⎛          2⎞       ↪
# ↪                                                          ⎜⎛d       ⎞ ⎟       ↪
# ↪                                                          ⎜⎜──(R(z))⎟ ⎟   ⋅R( ↪
# ↪                                                          ⎝⎝dz      ⎠ ⎠       ↪
#
# ↪
# ↪
# ↪
# ↪   7
# ↪  ⎞
# ↪ )⎟
# ↪  ⎠
# ↪ ───
# ↪
# ↪
# ↪
# ↪ z)
# ↪

# %%
simplify(ezz)
# Out:
#                                                                                ↪
#    ⎛        _______      _____________                             ___________ ↪
#    ⎜       ╱  2         ╱           2                             ╱            ↪
#  2 ⎜      ╱  R (z)     ╱  ⎛d       ⎞    2    ∂                   ╱  ⎛d       ⎞ ↪
# r ⋅⎜2⋅   ╱   ───── ⋅  ╱   ⎜──(R(z))⎟  ⋅R (z)⋅──(v(x, y, z)) -   ╱   ⎜──(R(z))⎟ ↪
#    ⎜    ╱      2    ╲╱    ⎝dz      ⎠         ∂z               ╲╱    ⎝dz      ⎠ ↪
#    ⎝  ╲╱      r                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                              4 ↪
#                                                               6    ⎛d       ⎞  ↪
#                                                            8⋅R (z)⋅⎜──(R(z))⎟  ↪
#                                                                    ⎝dz      ⎠  ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪ __                                                        ⎞                  ↪
# ↪ 2                                         2               ⎟                  ↪
# ↪     2    ∂                 2    ⎛d       ⎞  ∂             ⎟                  ↪
# ↪   ⋅R (z)⋅──(w(x, y, z)) + R (z)⋅⎜──(R(z))⎟ ⋅──(w(x, y, z))⎟    ⎛∂            ↪
# ↪          ∂y                     ⎝dz      ⎠  ∂y            ⎟    ⎜──(u(x, y, z ↪
# ↪                                                           ⎠    ⎝∂z           ↪
# ↪ ──────────────────────────────────────────────────────────── + ───────────── ↪
# ↪                                                                              ↪
# ↪                                                                    ⎛d        ↪
# ↪                                                                  2⋅⎜──(R(z)) ↪
# ↪                                                                    ⎝dz       ↪
# ↪                                                                              ↪
#
# ↪
# ↪
# ↪
# ↪    2                   2             6
# ↪   ⎞    ⎛∂             ⎞    ⎛d       ⎞  ∂
# ↪ ))⎟    ⎜──(w(x, y, z))⎟    ⎜──(R(z))⎟ ⋅──(w(x, y, z))
# ↪   ⎠    ⎝∂z            ⎠    ⎝dz      ⎠  ∂z
# ↪ ──── + ───────────────── + ──────────────────────────
# ↪  2                   2                       7/2
# ↪ ⎞          ⎛d       ⎞           ⎛          2⎞
# ↪ ⎟        2⋅⎜──(R(z))⎟           ⎜⎛d       ⎞ ⎟
# ↪ ⎠          ⎝dz      ⎠           ⎜⎜──(R(z))⎟ ⎟
# ↪                                 ⎝⎝dz      ⎠ ⎠

# %%
simplify(gxy)
# Out:
#                             d        ∂                           d        ∂    ↪
#                  v(x, y, z)⋅──(R(z))⋅──(w(x, y, z))   w(x, y, z)⋅──(R(z))⋅──(v ↪
# ∂                           dz       ∂x                          dz       ∂x   ↪
# ──(v(x, y, z)) - ────────────────────────────────── + ──────────────────────── ↪
# ∂x                         _____________                        _____________  ↪
#                           ╱           2                        ╱           2   ↪
#                          ╱  ⎛d       ⎞                        ╱  ⎛d       ⎞    ↪
#                         ╱   ⎜──(R(z))⎟  ⋅R(z)                ╱   ⎜──(R(z))⎟  ⋅ ↪
#                       ╲╱    ⎝dz      ⎠                     ╲╱    ⎝dz      ⎠    ↪
#                                                                                ↪
#
# ↪              ∂              ∂                ∂                ∂              ↪
# ↪ (x, y, z))   ──(u(x, y, z))⋅──(u(x, y, z))   ──(u(x, y, z))   ──(v(x, y, z)) ↪
# ↪              ∂x             ∂y               ∂y               ∂x             ↪
# ↪ ────────── + ───────────────────────────── + ────────────── + ────────────── ↪
# ↪                            _______                 _______                   ↪
# ↪                           ╱  2                    ╱  2                     ╱ ↪
# ↪                          ╱  R (z)                ╱  R (z)                 ╱  ↪
# ↪ R(z)                    ╱   ─────               ╱   ─────                ╱   ↪
# ↪                        ╱      2                ╱      2                 ╱    ↪
# ↪                      ╲╱      r               ╲╱      r                ╲╱     ↪
#
# ↪  ∂                ∂              ∂                  ∂              ∂         ↪
# ↪ ⋅──(v(x, y, z))   ──(w(x, y, z))⋅──(w(x, y, z))     ──(w(x, y, z))⋅──(w(x, y ↪
# ↪  ∂y               ∂x             ∂y                 ∂x             ∂y        ↪
# ↪ ─────────────── + ───────────────────────────── + ────────────────────────── ↪
# ↪ _______                          _______                  _______      _____ ↪
# ↪   2                             ╱  2                     ╱  2         ╱      ↪
# ↪  R (z)                         ╱  R (z)                 ╱  R (z)     ╱  ⎛d   ↪
# ↪  ─────                   2⋅   ╱   ─────           2⋅   ╱   ───── ⋅  ╱   ⎜──( ↪
# ↪    2                         ╱      2                 ╱      2    ╲╱    ⎝dz  ↪
# ↪   r                        ╲╱      r                ╲╱      r                ↪
#
# ↪
# ↪ , z))
# ↪
# ↪ ────────
# ↪ ________
# ↪       2
# ↪      ⎞
# ↪ R(z))⎟
# ↪      ⎠
# ↪

# %%
simplify(gxz)
# Out:
#          _______      _____________                                          _ ↪
#         ╱  2         ╱           2                                          ╱  ↪
#  2     ╱  R (z)     ╱  ⎛d       ⎞   ∂              ∂                 2     ╱   ↪
# r ⋅   ╱   ───── ⋅  ╱   ⎜──(R(z))⎟  ⋅──(v(x, y, z))⋅──(w(x, y, z))   r ⋅   ╱    ↪
#      ╱      2    ╲╱    ⎝dz      ⎠   ∂x             ∂y                    ╱     ↪
#    ╲╱      r                                                           ╲╱      ↪
# ───────────────────────────────────────────────────────────────── - ────────── ↪
#                                 2                                              ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪ ______                                                                       ↪
# ↪  2                                                                           ↪
# ↪ R (z)  ∂              ∂                                                      ↪
# ↪ ───── ⋅──(v(x, y, z))⋅──(w(x, y, z))        _____________                    ↪
# ↪   2    ∂x             ∂y                   ╱           2                     ↪
# ↪  r                                        ╱  ⎛d       ⎞    2    ∂            ↪
# ↪ ──────────────────────────────────── +   ╱   ⎜──(R(z))⎟  ⋅R (z)⋅──(w(x, y, z ↪
# ↪             2                          ╲╱    ⎝dz      ⎠         ∂x           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                              _____________   ↪
# ↪                                                             ╱           2    ↪
# ↪                                                            ╱  ⎛d       ⎞     ↪
# ↪                                                           ╱   ⎜──(R(z))⎟  ⋅R ↪
# ↪                                                         ╲╱    ⎝dz      ⎠     ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2    ∂              ∂                 2    ∂                 2    ∂    ↪
# ↪ )) + R (z)⋅──(u(x, y, z))⋅──(u(x, y, z)) + R (z)⋅──(u(x, y, z)) + R (z)⋅──(v ↪
# ↪            ∂x             ∂z                     ∂z                     ∂x   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ 2                                                                            ↪
# ↪  (z)                                                                         ↪
# ↪                                                                              ↪
#
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪            ∂                 2    ∂              ∂
# ↪ (x, y, z))⋅──(v(x, y, z)) + R (z)⋅──(w(x, y, z))⋅──(w(x, y, z))
# ↪            ∂z                     ∂x             ∂z
# ↪ ───────────────────────────────────────────────────────────────
# ↪
# ↪
# ↪
# ↪
# ↪

# %%
simplify(gyz)
# Out:
#            _______              5/2                                            ↪
#           ╱  2     ⎛          2⎞              2                                ↪
#    2     ╱  R (z)  ⎜⎛d       ⎞ ⎟    ⎛d       ⎞  ∂              ∂               ↪
# - r ⋅   ╱   ───── ⋅⎜⎜──(R(z))⎟ ⎟   ⋅⎜──(R(z))⎟ ⋅──(v(x, y, z))⋅──(w(x, y, z))  ↪
#        ╱      2    ⎝⎝dz      ⎠ ⎠    ⎝dz      ⎠  ∂y             ∂y              ↪
#      ╲╱      r                                                                 ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪            _______                                                     _____ ↪
# ↪           ╱  2               8                                        ╱  2   ↪
# ↪    2     ╱  R (z)  ⎛d       ⎞  ∂              ∂                      ╱  R (z ↪
# ↪ + r ⋅   ╱   ───── ⋅⎜──(R(z))⎟ ⋅──(v(x, y, z))⋅──(w(x, y, z)) + 2⋅   ╱   ──── ↪
# ↪        ╱      2    ⎝dz      ⎠  ∂y             ∂y                   ╱      2  ↪
# ↪      ╲╱      r                                                   ╲╱      r   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ __              7/2                                _______              7/2  ↪
# ↪    ⎛          2⎞                                  ╱  2     ⎛          2⎞     ↪
# ↪ )  ⎜⎛d       ⎞ ⎟     2    ∂                      ╱  R (z)  ⎜⎛d       ⎞ ⎟     ↪
# ↪ ─ ⋅⎜⎜──(R(z))⎟ ⎟   ⋅R (z)⋅──(v(x, y, z)) - 2⋅   ╱   ───── ⋅⎜⎜──(R(z))⎟ ⎟   ⋅ ↪
# ↪    ⎝⎝dz      ⎠ ⎠          ∂z                   ╱      2    ⎝⎝dz      ⎠ ⎠     ↪
# ↪                                              ╲╱      r                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                    _______                                   ↪
# ↪                                   ╱  2                               7       ↪
# ↪                 d                ╱  R (z)                  ⎛d       ⎞  ∂     ↪
# ↪ R(z)⋅v(x, y, z)⋅──(R(z)) - 2⋅   ╱   ───── ⋅R(z)⋅v(x, y, z)⋅⎜──(R(z))⎟ ⋅──(w( ↪
# ↪                 dz             ╱      2                    ⎝dz      ⎠  ∂z    ↪
# ↪                              ╲╱      r                                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                     _______                                                  ↪
# ↪                    ╱  2                               7                    ⎛ ↪
# ↪                   ╱  R (z)                  ⎛d       ⎞  ∂                  ⎜ ↪
# ↪ x, y, z)) + 2⋅   ╱   ───── ⋅R(z)⋅w(x, y, z)⋅⎜──(R(z))⎟ ⋅──(v(x, y, z)) + 2⋅⎜ ↪
# ↪                 ╱      2                    ⎝dz      ⎠  ∂z                 ⎝ ↪
# ↪               ╲╱      r                                                      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                           3/ ↪
# ↪                                                                    ⎛ 2   ⎞   ↪
# ↪                                                                  2 ⎜R (z)⎟   ↪
# ↪                                                               2⋅r ⋅⎜─────⎟   ↪
# ↪                                                                    ⎜  2  ⎟   ↪
# ↪                                                                    ⎝ r   ⎠   ↪
#
# ↪             7/2                                                      5/2     ↪
# ↪           2⎞                                            ⎛          2⎞        ↪
# ↪ ⎛d       ⎞ ⎟     2    ∂              ∂                  ⎜⎛d       ⎞ ⎟     2  ↪
# ↪ ⎜──(R(z))⎟ ⎟   ⋅R (z)⋅──(u(x, y, z))⋅──(u(x, y, z)) + 2⋅⎜⎜──(R(z))⎟ ⎟   ⋅R ( ↪
# ↪ ⎝dz      ⎠ ⎠          ∂y             ∂z                 ⎝⎝dz      ⎠ ⎠        ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ 2                                                                            ↪
# ↪             8                                                                ↪
# ↪   ⎛d       ⎞                                                                 ↪
# ↪  ⋅⎜──(R(z))⎟                                                                 ↪
# ↪   ⎝dz      ⎠                                                                 ↪
# ↪                                                                              ↪
#
# ↪                                                             5/2              ↪
# ↪              2                                 ⎛          2⎞                 ↪
# ↪    ⎛d       ⎞  ∂              ∂                ⎜⎛d       ⎞ ⎟     2    ⎛d     ↪
# ↪ z)⋅⎜──(R(z))⎟ ⋅──(v(x, y, z))⋅──(v(x, y, z)) + ⎜⎜──(R(z))⎟ ⎟   ⋅R (z)⋅⎜──(R( ↪
# ↪    ⎝dz      ⎠  ∂y             ∂z               ⎝⎝dz      ⎠ ⎠          ⎝dz    ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                    5/2                       ↪
# ↪     2                                 ⎛          2⎞                          ↪
# ↪    ⎞  ∂              ∂                ⎜⎛d       ⎞ ⎟                    ⎛d    ↪
# ↪ z))⎟ ⋅──(w(x, y, z))⋅──(w(x, y, z)) + ⎜⎜──(R(z))⎟ ⎟   ⋅R(z)⋅w(x, y, z)⋅⎜──(R ↪
# ↪    ⎠  ∂y             ∂z               ⎝⎝dz      ⎠ ⎠                    ⎝dz   ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪      3                                    8                                  ↪
# ↪     ⎞  ∂                   2    ⎛d       ⎞  ∂                 2    ⎛d        ↪
# ↪ (z))⎟ ⋅──(w(x, y, z)) + 2⋅R (z)⋅⎜──(R(z))⎟ ⋅──(w(x, y, z)) + R (z)⋅⎜──(R(z)) ↪
# ↪     ⎠  ∂y                       ⎝dz      ⎠  ∂y                     ⎝dz       ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪  6                                                           7               ↪
# ↪ ⎞  ∂              ∂                                ⎛d       ⎞  ∂             ↪
# ↪ ⎟ ⋅──(w(x, y, z))⋅──(w(x, y, z)) - R(z)⋅w(x, y, z)⋅⎜──(R(z))⎟ ⋅──(w(x, y, z) ↪
# ↪ ⎠  ∂y             ∂z                               ⎝dz      ⎠  ∂y            ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪
# ↪
# ↪
# ↪ )
# ↪
# ↪
# ↪ ─
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪
