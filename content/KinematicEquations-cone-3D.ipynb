# %% [markdown]
# Nonlinear cylinder 3D kinematics (strain-displacement relations)
# ---
# Engineering Mechanics Stability
#
# Graduate School Course
#
# Author: Saullo G. P. Castro
#
# Date: 8 July 2025

# %%
from sympy import Function, Symbol, sqrt, cos, sin
from sympy import init_printing, simplify, expand

alpha = Symbol('alpha', constant=True)
r = Symbol('r', constant=True)
x = Symbol('x')
theta = Symbol('theta')
z = Symbol('z')
u = Function('u')(x,theta,z)
v = Function('v')(x,theta,z)
w = Function('w')(x,theta,z)
R = Function('R')(x,z)

NL = 0 # NOTE set to 1 for full nonlinear relations, 0 for linear relations

# Global coordinates
X1 = R*cos(theta)
X2 = R*sin(theta)
X3 = z*sin(alpha) - x*cos(alpha)

# Local coordinates
x1 = x
x2 = theta
x3 = z

H1 = sqrt(X1.diff(x1)**2 + X2.diff(x1)**2 + X3.diff(x1)**2)
H2 = sqrt(X1.diff(x2)**2 + X2.diff(x2)**2 + X3.diff(x2)**2)
H3 = sqrt(X1.diff(x3)**2 + X2.diff(x3)**2 + X3.diff(x3)**2)
                
w1 = ((H1*w).diff(x2) - (H2*v).diff(x3))/(2*H2*H3)
w2 = ((H1*u).diff(x3) - (H3*w).diff(x1))/(2*H1*H3)
w3 = ((H2*v).diff(x1) - (H1*u).diff(x2))/(2*H1*H2)

e11 = u.diff(x1)/H1 + v*H1.diff(x2)/(H1*H2) + w*H1.diff(x3)/(H1*H3)
e22 = u*H2.diff(x1)/(H1*H2) + v.diff(x2)/H2 + w*H2.diff(x3)/(H2*H3)
e33 = u*H3.diff(x1)/(H1*H3) + v*H3.diff(x2)/(H2*H3) + w.diff(x3)/H3
e12 = H1*(u/H1).diff(x2)/H2 + H2*(v/H2).diff(x1)/H1
e13 = H1*(u/H1).diff(x3)/H3 + H3*(w/H3).diff(x1)/H1
e23 = H2*(v/H2).diff(x3)/H3 + H3*(w/H3).diff(x2)/H2

ep11 = ((e13/2 - w2)**2 + (e12/2 + w3)**2 + e11**2)/2*NL + e11
ep22 = ((e23/2 + w1)**2 + (e12/2 - w3)**2 + e22**2)/2*NL + e22
ep33 = ((e23/2 - w1)**2 + (e13/2 + w2)**2 + e33**2)/2*NL + e33
ep12 = ((e23/2 + w1)*(e13/2 - w2) + e11*(e12/2 - w3) + e22*(e12/2 + w3))*NL + e12
ep13 = (e33*(e13/2 - w2) + e11*(e13/2 + w2) + (e23/2 - w1)*(e12/2 + w3))*NL + e13
ep23 = (e22*(e23/2 - w1) + e33*(e23/2 + w1) + (e13/2 + w2)*(e12/2 - w3))*NL + e23

exx = ep11
ett = ep22
ezz = ep33
gxt = ep12
gxz = ep13
gtz = ep23

# %% [markdown]
# Printing kinematic equations
# ---
# The following order is printed next:
#
# $\varepsilon_{xx}$
# $\varepsilon_{\theta\theta}$
# $\varepsilon_{zz}$
# $\gamma_{x\theta}$
# $\gamma_{xz}$
# $\gamma_{\theta z}$

# %%
init_printing()

# %%
simplify(exx)
# Out:
#      __________________________                                                ↪
#     ╱                        2  ⎛                       2⎞                     ↪
#    ╱     2      ⎛∂          ⎞   ⎜   2      ⎛∂          ⎞ ⎟ ∂                   ↪
#   ╱   sin (α) + ⎜──(R(x, z))⎟  ⋅⎜cos (α) + ⎜──(R(x, z))⎟ ⎟⋅──(u(x, θ, z)) +    ↪
# ╲╱              ⎝∂z         ⎠   ⎝          ⎝∂x         ⎠ ⎠ ∂x               ╲╱ ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                __________________________      ↪
#                                               ╱                        2  ⎛    ↪
#                                              ╱     2      ⎛∂          ⎞   ⎜    ↪
#                                             ╱   sin (α) + ⎜──(R(x, z))⎟  ⋅⎜cos ↪
#                                           ╲╱              ⎝∂z         ⎠   ⎝    ↪
#
# ↪    __________________________
# ↪   ╱                        2                           2
# ↪  ╱     2      ⎛∂          ⎞              ∂            ∂
# ↪ ╱   cos (α) + ⎜──(R(x, z))⎟  ⋅w(x, θ, z)⋅──(R(x, z))⋅─────(R(x, z))
# ↪               ⎝∂x         ⎠              ∂x          ∂z ∂x
# ↪ ───────────────────────────────────────────────────────────────────
# ↪                       3/2
# ↪                     2⎞
# ↪ 2      ⎛∂          ⎞ ⎟
# ↪  (α) + ⎜──(R(x, z))⎟ ⎟
# ↪        ⎝∂x         ⎠ ⎠

# %%
simplify(ett)
# Out:
# ∂                                      ∂                                       ↪
# ──(v(x, θ, z))              u(x, θ, z)⋅──(R(x, z))                       w(x,  ↪
# ∂θ                                     ∂x                                      ↪
# ────────────── + ───────────────────────────────────────────── + ───────────── ↪
#    __________         ________________________________                ________ ↪
#   ╱  2               ╱                          2                    ╱         ↪
# ╲╱  R (x, z)        ╱       2      ⎛∂          ⎞                    ╱     2    ↪
#                    ╱   - sin (α) + ⎜──(R(x, z))⎟  + 1 ⋅R(x, z)     ╱   sin (α) ↪
#                  ╲╱                ⎝∂x         ⎠                 ╲╱            ↪
#
# ↪       ∂
# ↪ θ, z)⋅──(R(x, z))
# ↪       ∂z
# ↪ ──────────────────────────
# ↪ __________________
# ↪                 2
# ↪    ⎛∂          ⎞
# ↪  + ⎜──(R(x, z))⎟  ⋅R(x, z)
# ↪    ⎝∂z         ⎠

# %%
simplify(ezz)
# Out:
#      __________________________                                                ↪
#     ╱                        2                           2              ⎛      ↪
#    ╱     2      ⎛∂          ⎞              ∂            ∂               ⎜   2  ↪
#   ╱   sin (α) + ⎜──(R(x, z))⎟  ⋅u(x, θ, z)⋅──(R(x, z))⋅─────(R(x, z)) + ⎜sin ( ↪
# ╲╱              ⎝∂z         ⎠              ∂z          ∂z ∂x            ⎝      ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                     3/2      _ ↪
#                                           ⎛                       2⎞        ╱  ↪
#                                           ⎜   2      ⎛∂          ⎞ ⎟       ╱   ↪
#                                           ⎜sin (α) + ⎜──(R(x, z))⎟ ⎟   ⋅  ╱    ↪
#                                           ⎝          ⎝∂z         ⎠ ⎠    ╲╱     ↪
#
# ↪                           __________________________
# ↪                   2⎞     ╱                        2
# ↪      ⎛∂          ⎞ ⎟    ╱     2      ⎛∂          ⎞   ∂
# ↪ α) + ⎜──(R(x, z))⎟ ⎟⋅  ╱   cos (α) + ⎜──(R(x, z))⎟  ⋅──(w(x, θ, z))
# ↪      ⎝∂z         ⎠ ⎠ ╲╱              ⎝∂x         ⎠   ∂z
# ↪ ───────────────────────────────────────────────────────────────────
# ↪ _________________________
# ↪                        2
# ↪    2      ⎛∂          ⎞
# ↪ cos (α) + ⎜──(R(x, z))⎟
# ↪           ⎝∂x         ⎠

# %%
simplify(gxt)
# Out:
#         3/2                                                                    ↪
#  2          ∂                        ∂                                         ↪
# R (x, z)   ⋅──(u(x, θ, z))           ──(v(x, θ, z))                    v(x, θ, ↪
#             ∂θ                       ∂x                                        ↪
# ────────────────────────── + ─────────────────────────────── - ─────────────── ↪
#           4                       __________________________        __________ ↪
#          R (x, z)                ╱                        2        ╱           ↪
#                                 ╱     2      ⎛∂          ⎞        ╱     2      ↪
#                                ╱   cos (α) + ⎜──(R(x, z))⎟       ╱   cos (α) + ↪
#                              ╲╱              ⎝∂x         ⎠     ╲╱              ↪
#
# ↪
# ↪     ∂
# ↪  z)⋅──(R(x, z))
# ↪     ∂x
# ↪ ────────────────────────
# ↪ ________________
# ↪               2
# ↪  ⎛∂          ⎞
# ↪  ⎜──(R(x, z))⎟  ⋅R(x, z)
# ↪  ⎝∂x         ⎠

# %%
simplify(gxz)
# Out:
#                                                                                ↪
# ⎛⎛                       2⎞                                           2        ↪
# ⎜⎜   2      ⎛∂          ⎞ ⎟ ∂                           ∂            ∂         ↪
# ⎜⎜sin (α) + ⎜──(R(x, z))⎟ ⎟⋅──(w(x, θ, z)) - w(x, θ, z)⋅──(R(x, z))⋅─────(R(x, ↪
# ⎝⎝          ⎝∂z         ⎠ ⎠ ∂x                          ∂z          ∂z ∂x      ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                                            3/2               ↪
# ↪     ⎞ ⎛                       2⎞ ⎛                       2⎞      ⎛⎛          ↪
# ↪     ⎟ ⎜   2      ⎛∂          ⎞ ⎟ ⎜   2      ⎛∂          ⎞ ⎟      ⎜⎜   2      ↪
# ↪  z))⎟⋅⎜sin (α) + ⎜──(R(x, z))⎟ ⎟⋅⎜cos (α) + ⎜──(R(x, z))⎟ ⎟    + ⎜⎜cos (α) + ↪
# ↪     ⎠ ⎝          ⎝∂z         ⎠ ⎠ ⎝          ⎝∂x         ⎠ ⎠      ⎝⎝          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                               2              ↪
# ↪                                     ⎛                       2⎞  ⎛            ↪
# ↪                                     ⎜   2      ⎛∂          ⎞ ⎟  ⎜   2      ⎛ ↪
# ↪                                     ⎜sin (α) + ⎜──(R(x, z))⎟ ⎟ ⋅⎜cos (α) + ⎜ ↪
# ↪                                     ⎝          ⎝∂z         ⎠ ⎠  ⎝          ⎝ ↪
#
# ↪                                                                              ↪
# ↪               2⎞                                           2           ⎞ ⎛   ↪
# ↪  ⎛∂          ⎞ ⎟ ∂                           ∂            ∂            ⎟ ⎜   ↪
# ↪  ⎜──(R(x, z))⎟ ⎟⋅──(u(x, θ, z)) - u(x, θ, z)⋅──(R(x, z))⋅─────(R(x, z))⎟⋅⎜si ↪
# ↪  ⎝∂x         ⎠ ⎠ ∂z                          ∂x          ∂z ∂x         ⎠ ⎝   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪               2                                                              ↪
# ↪             2⎞                                                               ↪
# ↪ ∂          ⎞ ⎟                                                               ↪
# ↪ ──(R(x, z))⎟ ⎟                                                               ↪
# ↪ ∂x         ⎠ ⎠                                                               ↪
#
# ↪                        3/2
# ↪                      2⎞    ⎛                       2⎞
# ↪  2      ⎛∂          ⎞ ⎟    ⎜   2      ⎛∂          ⎞ ⎟
# ↪ n (α) + ⎜──(R(x, z))⎟ ⎟   ⋅⎜cos (α) + ⎜──(R(x, z))⎟ ⎟
# ↪         ⎝∂z         ⎠ ⎠    ⎝          ⎝∂x         ⎠ ⎠
# ↪ ─────────────────────────────────────────────────────
# ↪
# ↪
# ↪
# ↪
# ↪

# %%
simplify(gtz)
# Out:
#         3/2                                                                    ↪
#  2          ∂                        ∂                                         ↪
# R (x, z)   ⋅──(w(x, θ, z))           ──(v(x, θ, z))                    v(x, θ, ↪
#             ∂θ                       ∂z                                        ↪
# ────────────────────────── + ─────────────────────────────── - ─────────────── ↪
#           4                       __________________________        __________ ↪
#          R (x, z)                ╱                        2        ╱           ↪
#                                 ╱     2      ⎛∂          ⎞        ╱     2      ↪
#                                ╱   sin (α) + ⎜──(R(x, z))⎟       ╱   sin (α) + ↪
#                              ╲╱              ⎝∂z         ⎠     ╲╱              ↪
#
# ↪
# ↪     ∂
# ↪  z)⋅──(R(x, z))
# ↪     ∂z
# ↪ ────────────────────────
# ↪ ________________
# ↪               2
# ↪  ⎛∂          ⎞
# ↪  ⎜──(R(x, z))⎟  ⋅R(x, z)
# ↪  ⎝∂z         ⎠
